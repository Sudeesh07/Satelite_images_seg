mask.png
# /kaggle/input/deepglobe-road-extraction-dataset/train/405717_sat.jpg
# /kaggle/input/deepglobe-road-extraction-dataset/train/244466_mask.png
# /kaggle/input/deepglobe-road-extraction-dataset/train/597803_sat.jpg
# /kaggle/input/deepglobe-road-extraction-dataset/train/191523_mask.png
# /kaggle/input/deepglobe-road-extraction-dataset/train/299564_sat.jpg
# /kaggle/input/deepglobe-road-extraction-dataset/train/59797_mask.png
# /kaggle/input/deepglobe-road-extraction-dataset/train/381525_sat.jpg
# /kaggle/input/deepglobe-road-extraction-dataset/train/12023_sat.jpg
# /kaggle/input/deepglobe-road-extraction-dataset/train/320163_mask.png
# /kaggle/input/deepglobe-road-extraction-dataset/train/24405_sat.jpg
# /kaggle/input/deepglobe-road-extraction-dataset/train/986182_sat.jpg
# /kaggle/input/deepglobe-road-extraction-dataset/train/663316_sat.jpg
# /kaggle/input/deepglobe-road-extraction-dataset/train/202076_mask.png
# /kaggle/input/deepglobe-road-extraction-dataset/train/408303_sat.jpg
# /kaggle/input/deepglobe-road-extraction-dataset/train/34523_sat.jpg
# /kaggle/input/deepglobe-road-extraction-dataset/train/694729_sat.jpg
# /kaggle/input/deepglobe-road-extraction-dataset/train/440978_sat.jpg
# /kaggle/input/deepglobe-road-extraction-dataset/train/141378_sat.jpg
# /kaggle/input/deepglobe-road-extraction-dataset/train/240340_sat.jpg
# /kaggle/input/deepglobe-road-extraction-dataset/train/316440_mask.png
# /kaggle/input/deepglobe-road-extraction-dataset/train/567919_sat.jpg
# /kaggle/input/deepglobe-road-extraction-dataset/train/829522_sat.jpg
# /kaggle/input/deepglobe-road-extraction-dataset/train/156501_mask.png
# /kaggle/input/deepglobe-road-extraction-dataset/train/485516_mask.png
# /kaggle/input/deepglobe-road-extraction-dataset/train/627_mask.png
# /kaggle/input/deepglobe-road-extraction-dataset/train/668861_sat.jpg
# /kaggle/input/deepglobe-road-extraction-dataset/train/799678_sat.jpg
# /kaggle/input/deepglobe-road-extraction-dataset/train/755575_sat.jpg
# /kaggle/input/deepglobe-road-extraction-dataset/train/507376_sat.jpg
# /kaggle/input/deepglobe-road-extraction-dataset/train/99884_sat.jpg
# /kaggle/input/deepglobe-road-extraction-dataset/train/344565_sat.jpg
# /kaggle/input/deepglobe-road-extraction-dataset/train/594865_mask.png
# /kaggle/input/deepglobe-road-extraction-dataset/train/275185_sat.jpg
# /kaggle/input/deepglobe-road-extraction-dataset/train/185247_sat.jpg
# /kaggle/input/deepglobe-road-extraction-dataset/train/174781_mask.png
# /kaggle/input/deepglobe-road-extraction-dataset/train/87662_mask.png
# /kaggle/input/deepglobe-road-extraction-dataset/train/804816_sat.jpg
# /kaggle/input/deepglobe-road-extraction-dataset/train/703960_sat.jpg
# /kaggle/input/deepglobe-road-extraction-dataset/train/317060_sat.jpg
# /kaggle/input/deepglobe-road-extraction-dataset/train/694261_sat.jpg
# /kaggle/input/deepglobe-road-extraction-dataset/train/742390_sat.jpg
# /kaggle/input/deepglobe-road-extraction-dataset/train/736761_mask.png
# /kaggle/input/deepglobe-road-extraction-dataset/train/922867_mask.png
# /kaggle/input/deepglobe-road-extraction-dataset/train/403428_mask.png
# /kaggle/input/deepglobe-road-extraction-dataset/train/187103_sat.jpg
# /kaggle/input/deepglobe-road-extraction-dataset/train/284729_sat.jpg
# /kaggle/input/deepglobe-road-extraction-dataset/train/828369_sat.jpg
# /kaggle/input/deepglobe-road-extraction-dataset/train/793205_mask.png
# /kaggle/input/deepglobe-road-extraction-dataset/train/893717_sat.jpg
# /kaggle/input/deepglobe-road-extraction-dataset/train/197293_sat.jpg
# /kaggle/input/deepglobe-road-extraction-dataset/train/370642_sat.jpg
# /kaggle/input/deepglobe-road-extraction-dataset/train/690443_mask.png
# /kaggle/input/deepglobe-road-extraction-dataset/train/582884_sat.jpg
# /kaggle/input/deepglobe-road-extraction-dataset/train/774528_mask.png
# /kaggle/input/deepglobe-road-extraction-dataset/train/976309_sat.jpg
# /kaggle/input/deepglobe-road-extraction-dataset/train/149125_mask.png
# /kaggle/input/deepglobe-road-extraction-dataset/train/627222_mask.png
# /kaggle/input/deepglobe-road-extraction-dataset/train/929277_mask.png
# /kaggle/input/deepglobe-road-extraction-dataset/train/218931_sat.jpg
# /kaggle/input/deepglobe-road-extraction-dataset/train/859110_mask.png
# /kaggle/input/deepglobe-road-extraction-dataset/train/592479_sat.jpg
# /kaggle/input/deepglobe-road-extraction-dataset/train/820463_sat.jpg
# /kaggle/input/deepglobe-road-extraction-dataset/train/491843_sat.jpg
# /kaggle/input/deepglobe-road-extraction-dataset/train/879122_sat.jpg
# /kaggle/input/deepglobe-road-extraction-dataset/train/723483_mask.png
# /kaggle/input/deepglobe-road-extraction-dataset/train/334908_mask.png
# /kaggle/input/deepglobe-road-extraction-dataset/train/733110_mask.png
# /kaggle/input/deepglobe-road-extraction-dataset/train/536023_mask.png
# /kaggle/input/deepglobe-road-extraction-dataset/train/167439_sat.jpg
# /kaggle/input/deepglobe-road-extraction-dataset/train/838447_mask.png
# /kaggle/input/deepglobe-road-extraction-dataset/train/549813_sat.jpg
# /kaggle/input/deepglobe-road-extraction-dataset/train/82060_mask.png
# /kaggle/input/deepglobe-road-extraction-dataset/train/622199_mask.png
# /kaggle/input/deepglobe-road-extraction-dataset/train/45040_mask.png
# /kaggle/input/deepglobe-road-extraction-dataset/train/2495_mask.png
# /kaggle/input/deepglobe-road-extraction-dataset/train/191119_mask.png
# /kaggle/input/deepglobe-road-extraction-dataset/train/731685_mask.png
# /kaggle/input/deepglobe-road-extraction-dataset/train/771348_sat.jpg
# /kaggle/input/deepglobe-road-extraction-dataset/train/474132_sat.jpg
# /kaggle/input/deepglobe-road-extraction-dataset/train/139401_mask.png
# /kaggle/input/deepglobe-road-extraction-dataset/train/569991_mask.png
# /kaggle/input/deepglobe-road-extraction-dataset/train/285518_sat.jpg
# /kaggle/input/deepglobe-road-extraction-dataset/train/739225_mask.png
# /kaggle/input/deepglobe-road-extraction-dataset/train/753215_mask.png
# /kaggle/input/deepglobe-road-extraction-dataset/train/197342_sat.jpg
# /kaggle/input/deepglobe-road-extraction-dataset/train/776852_mask.png

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn
import cv2
from glob import glob
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import Recall, Precision
from tensorflow.keras import backend as K
from tensorflow.keras.layers import Conv2D, BatchNormalization, Activation, MaxPool2D, Conv2DTranspose, Concatenate, Input
from tensorflow.keras.models import Model
from PIL import Image
import random
from keras.utils import normalize

# %%
H=W=256
lr=0.0001

# %%
from glob import glob
data_path = "/kaggle/input/deepglobe-road-extraction-dataset/train"
mask_files = sorted(glob(data_path + '/*mask.png'))
sat_files = sorted(glob(data_path + '/*sat.jpg'))
print(len(mask_files), len(sat_files))

# %%
def load_data(data_path, split=0.2):
    masks = sorted(glob(data_path + '/*mask.png'))
    images = sorted(glob(data_path + '/*sat.jpg'))
    size = int(len(images) * split)
    
    train_x, valid_x = train_test_split(images, test_size=0.2, random_state=42)
    train_y, valid_y = train_test_split(masks, test_size=0.2, random_state=42)
    
    train_x, test_x = train_test_split(train_x, test_size=0.2, random_state=42)
    train_y, test_y = train_test_split(train_y, test_size=0.2, random_state=42)
    
    return (train_x, train_y), (valid_x, valid_y), (test_x, test_y)

data_path = "/kaggle/input/deepglobe-road-extraction-dataset/train"
(train_x, train_y), (valid_x, valid_y), (test_x, test_y) = load_data(data_path)

len(train_x), len(train_y), len(valid_x), len(valid_y), len(test_x), len(test_y)

# %%
from PIL import Image
import numpy as np

def read_image(path):
    try:
        img = Image.open(path)
        img = img.resize((H,W), resample=Image.LANCZOS)
        x = np.array(img, dtype=np.float32)
        x = x / 255.0
        return x
    except Exception as e:
        print(f"Error while reading image: {e}")
        return None
    
    
def read_image_og(path):
    try:
        img = Image.open(path)
        x = np.array(img, dtype=np.float32)
        x = x / 255.0
        return x
    except Exception as e:
        print(f"Error while reading image: {e}")
        return None





def read_mask(path):
    try:
        img = Image.open(path).convert('L')
        img = img.resize((W, H))
        x = np.array(img, dtype=np.float32)
        x = x / 255.0
        x = np.expand_dims(x, axis=-1)
        return x
    except Exception as e:
        print(f"Error while reading mask: {e}")
        return None


def tf_parse(x, y):
    def _parse(x, y):
        x = read_image(x)
        y = read_mask(y)
        return x, y
    
    x, y = tf.numpy_function(_parse, [x, y], [tf.float32, tf.float32])
    x.set_shape([H, W, 3])
    y.set_shape([H, W, 1])
    return x, y


def tf_dataset(X, Y, batch=8):
    dataset = tf.data.Dataset.from_tensor_slices((X, Y))
    dataset = dataset.map(tf_parse)
    dataset = dataset.batch(batch)
    dataset = dataset.prefetch(10)
    
    return dataset

# %%
train_dataset = tf_dataset(train_x, train_y, batch=8)
valid_dataset = tf_dataset(valid_x, valid_y, batch=8)

train_steps = (len(train_x) // 8)
valid_steps = (len(valid_x) // 8)

# %%
def show_random_sample():
    rand_index =random.randint(0, len(train_x) - 1)
    plt.figure(figsize=(10, 5))  
    plt.subplot(1, 2, 1)  
    plt.imshow(read_image(train_x[rand_index]))
    plt.title('Image')
    

    plt.subplot(1, 2, 2)  
    plt.imshow(read_mask(train_y[rand_index]))
    plt.title('Mask')

    plt.show()

# %%
show_random_sample()

# %%
from keras.models import Model
from keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, concatenate, Conv2DTranspose, BatchNormalization, Dropout, Lambda

################################################################
def simple_unet_model(IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS):
#Build the model
    inputs = Input((IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS))
    #s = Lambda(lambda x: x / 255)(inputs)   #No need for this if we normalize our inputs beforehand
    s = inputs

    #Contraction path
    c1 = Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(s)
    c1 = Dropout(0.1)(c1)
    c1 = Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c1)
    p1 = MaxPooling2D((2, 2))(c1)
    
    c2 = Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p1)
    c2 = Dropout(0.1)(c2)
    c2 = Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c2)
    p2 = MaxPooling2D((2, 2))(c2)
     
    c3 = Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p2)
    c3 = Dropout(0.2)(c3)
    c3 = Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c3)
    p3 = MaxPooling2D((2, 2))(c3)
     
    c4 = Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p3)
    c4 = Dropout(0.2)(c4)
    c4 = Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c4)
    p4 = MaxPooling2D(pool_size=(2, 2))(c4)
     
    c5 = Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p4)
    c5 = Dropout(0.3)(c5)
    c5 = Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c5)
    
    #Expansive path 
    u6 = Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(c5)
    u6 = concatenate([u6, c4])
    c6 = Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u6)
    c6 = Dropout(0.2)(c6)
    c6 = Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c6)
     
    u7 = Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(c6)
    u7 = concatenate([u7, c3])
    c7 = Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u7)
    c7 = Dropout(0.2)(c7)
    c7 = Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c7)
     
    u8 = Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same')(c7)
    u8 = concatenate([u8, c2])
    c8 = Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u8)
    c8 = Dropout(0.1)(c8)
    c8 = Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c8)
     
    u9 = Conv2DTranspose(16, (2, 2), strides=(2, 2), padding='same')(c8)
    u9 = concatenate([u9, c1], axis=3)
    c9 = Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u9)
    c9 = Dropout(0.1)(c9)
    c9 = Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c9)
     
    outputs = Conv2D(1, (1, 1), activation='sigmoid')(c9)
     
    model = Model(inputs=[inputs], outputs=[outputs])
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    model.summary()
    
    return model

# %%
model = simple_unet_model(H,W,3)


#If starting with pre-trained weights. 
#model.load_weights('mitochondria_gpu_tf1.4.hdf5')

history = model.fit(train_dataset ,
                    batch_size =8, 
                    epochs=10, 
                    validation_data=valid_dataset, 
                    shuffle=False)

model.save('roadsegmentation_test.hdf5')


#plot the training and validation accuracy and loss at each epoch
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

acc = history.history['acc']
#acc = history.history['accuracy']
val_acc = history.history['val_acc']
#val_acc = history.history['val_accuracy']

plt.plot(epochs, acc, 'y', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
large_image = cv2.imread('/kaggle/input/lololol/upscaled_image.jpg')
print(large_image.shape)
#This will split the image into small images of shape [3,3]
patches = patchify(large_image, (256, 256,3), step=256)  #Step=256 for 256 patches means no overlap
print(patches.shape)

predicted_patches = []
for i in range(patches.shape[0]):
    for j in range(patches.shape[1]):
        for k in range(patches.shape[2]):
        
            single_patch = patches[i,j,0,:,:,:]
            single_patch_norm =np.expand_dims(normalize(np.array(single_patch), axis=1),0)
            print(single_patch_norm.shape)

#Predict and threshold for values above 0.5 probability
            single_patch_prediction = (model.predict(single_patch_norm)[:,:,:,:] > 0.5).astype(np.uint8)
            predicted_patches.append(single_patch_prediction)

predicted_patches = np.array(predicted_patches)
tri_channel_patches = np.repeat(predicted_patches[:, :, :,:], 3, axis=4)
tri_channel_patches.shape
predicted_patches_reshaped = np.reshape(tri_channel_patches, (patches.shape[0], patches.shape[1],patches.shape[2], 256,256,3) )
print(predicted_patches_reshaped.shape)
reconstructed_image = unpatchify(predicted_patches_reshaped, large_image.shape)
plt.imshow(reconstructed_image)
plt.hist(reconstructed_image.flatten())  #Threshold everything above 0
